# %%
import io

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from datasets import load_dataset

from experiment_utils.constants import DATA_DIR

# %%
# %matplotlib inline

# %%
data_files = {x.absolute().as_posix() for x in DATA_DIR.glob('**/*.parquet')}

# %%
dataset = load_dataset('parquet', data_files=data_files)
# Out:
# Using custom data configuration default-7fe720cef817f945
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset parquet downloaded and prepared to /home/shikhar/.cache/huggingface/datasets/parquet/default-7fe720cef817f945/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
first_sample = dataset['train']['image'][0]
first_sample

# %%
bytes_io = io.BytesIO(first_sample['bytes'])

# %%
first_sample_png = mpimg.imread(bytes_io, format='png')

# %%
plt.imshow(first_sample_png)
